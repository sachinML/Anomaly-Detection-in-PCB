# %%
import os

# %%
path = "D:\\nas\\ResultData\\Data\\AFVI11\\N971N(CSI1672M)\\661748-01-0000-01\\1"

# %%
# !cd "/content/drive/MyDrive/All_Practicals_Labs_Assignments_Projects/Raj_Anant_Tapase(202IS019)_Major_Project/Codes/final_dataset(ToNIT)/ResultData/Data/"

# %%
paths_with_file=[]
for i in os.walk(path):
  #if i[]
  for files in i[-1]:
    #print(files)
    #print(files[-7:])
    if files[-13:]=="_BC_Label.xml":
     # i[0].replace("\","\\")
      print(i[0])#.replace("/","//"))
      print(files[1:5])
      folder_path=str(i[0])+"/"
      file_path=folder_path+str(files)
      print(os.path.isfile(file_path)) 
      paths_with_file.append(i[0])
      #!ls i[0]
# Out:
# D:\nas\ResultData\Data\AFVI11\N971N(CSI1672M)\661748-01-0000-01\1\0001
# 0001
# True
# D:\nas\ResultData\Data\AFVI11\N971N(CSI1672M)\661748-01-0000-01\1\0002
# 0002
# True
# D:\nas\ResultData\Data\AFVI11\N971N(CSI1672M)\661748-01-0000-01\1\0003
# 0003
# True
# D:\nas\ResultData\Data\AFVI11\N971N(CSI1672M)\661748-01-0000-01\1\0004
# 0004
# True
# D:\nas\ResultData\Data\AFVI11\N971N(CSI1672M)\661748-01-0000-01\1\0005
# 0005
# True
# D:\nas\ResultData\Data\AFVI11\N971N(CSI1672M)\661748-01-0000-01\1\0006
# 0006
# True
# D:\nas\ResultData\Data\AFVI11\N971N(CSI1672M)\661748-01-0000-01\1\0007
# 0007
# True
# D:\nas\ResultData\Data\AFVI11\N971N(CSI1672M)\661748-01-0000-01\1\0008
# 0008
# True
# D:\nas\ResultData\Data\AFVI11\N971N(CSI1672M)\661748-01-0000-01\1\0009
# 0009
# True
# D:\nas\ResultData\Data\AFVI11\N971N(CSI1672M)\661748-01-0000-01\1\0010
# 0010
# True
# D:\nas\ResultData\Data\AFVI11\N971N(CSI1672M)\661748-01-0000-01\1\0011
# 0011
# True
# ...

# %%
len(paths_with_file)
# Out:
# 154

# %%
file_path
# Out:
# 'D:\\nas\\ResultData\\Data\\AFVI11\\N971N(CSI1672M)\\661748-01-0000-01\\1\\0154/S0154_BC_Label.xml'

# %%
for x in os.walk(path):
  print(x)
